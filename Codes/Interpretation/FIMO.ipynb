# %% [markdown]
# ## Preparation (mapping isoforms back to genes)

# %%
import os
import csv
import pandas as pd
import re
import subprocess
import numpy as np
import scipy.stats as stats

new_dir = "/home/jingqi/RNALocateV3.0"
os.chdir(new_dir)
os.getcwd()
# Out:
# '/home/jingqi/RNALocateV3.0'

# %% [markdown]
# ### Mapping

# %%
input_file = "Data/Raw/FASTA_full.txt"
output_file = "Data/Raw/gene_transcript_matrix.csv"

print(f"Reading from: {input_file}")

gene_to_transcripts = {}

with open(input_file, 'r') as f:
    for line in f:
        if line.startswith(">"):

            clean_line = line.strip()[1:] 
            parts = clean_line.split('|')
            
            if len(parts) >= 2:
                transcript_id = parts[0]
                gene_symbol = parts[1]
                
                # Add to dictionary
                if gene_symbol not in gene_to_transcripts:
                    gene_to_transcripts[gene_symbol] = []
                gene_to_transcripts[gene_symbol].append(transcript_id)

max_transcripts = 0
rows = []

for gene, transcripts in gene_to_transcripts.items():
    if len(transcripts) > max_transcripts:
        max_transcripts = len(transcripts)
    
    row = [gene] + transcripts
    rows.append(row)


print(f"Found {len(rows)} unique genes.")
print(f"Max transcripts for one gene: {max_transcripts}")

with open(output_file, "w", newline="") as f:
    writer = csv.writer(f)
    
    header = ["Gene_Symbol"] + [f"Transcript_{i+1}" for i in range(max_transcripts)]
    writer.writerow(header)
    
    writer.writerows(rows)
# Out:
# Reading from: Data/Raw/FASTA_full.txt
# Found 728 unique genes.
# Max transcripts for one gene: 102
# ------------------------------
# Success! Matrix saved to: Data/Raw/gene_transcript_matrix.csv

# %% [markdown]
# ### little validation (can skip)

# %%
final_gene_list = []
with open("Data/Raw/final_gene_list.txt", "r") as f:
    for line in f:
        gene = line.strip()
        if gene:
            final_gene_list.append(gene)

original_set = set(final_gene_list)

matrix_df = pd.read_csv("Data/Raw/gene_transcript_matrix.csv")
found_set = set(matrix_df['Gene_Symbol'].unique())

missing_genes = original_set - found_set
print(missing_genes)
# Out:
# 736
# 728
# 7
# {'ENSMUSG00000125456', 'ENSMUSG00000121480', 'ENSMUSG00000143377', 'ENSMUSG00000132887', 'ENSMUSG00000135935', '2810004N23Rik', 'ENSMUSG00000124710'}

# %% [markdown]
# ## Assign SCL on to isoforms

# %% [markdown]
# ### Extract the motifs validated

# %%
df_longer = pd.read_csv("Data/TOMTOM/tomtom_longer_filtered.csv")
df_shorter = pd.read_csv("Data/TOMTOM/tomtom_shorter_filtered.csv")

# Get unique target motif IDs
targets_longer = set(df_longer['Target'].dropna().unique())
targets_shorter = set(df_shorter['Target'].dropna().unique())
all_targets = targets_longer | targets_shorter

print(f"Unique targets from longer: {len(targets_longer)}")
print(f"Unique targets from shorter: {len(targets_shorter)}")
print(f"Total unique targets: {len(all_targets)}")
# Out:
# Unique targets from longer: 57
# Unique targets from shorter: 149
# Total unique targets: 188
#
# Targets: ['mmu-miR-7086-5p', 'mmu-miR-6966-5p', 'mmu-miR-6919-3p', 'mmu-miR-124-3p', 'mmu-miR-204-5p', 'mmu-miR-6940-5p', 'mmu-miR-326-5p', 'mmu-miR-6968-5p', 'mmu-miR-12196-3p', 'mmu-miR-3090-5p']...

# %% [markdown]
# ### Get the seqeunces from database

# %%
def extract_motifs_from_meme_db(db_file, target_ids, output_file):
    """
    Extract specific motifs from a MEME database file.
    """
    with open(db_file, 'r') as f:
        content = f.read()
    
    # Split by MOTIF
    parts = re.split(r'(?=^MOTIF )', content, flags=re.MULTILINE)
    
    # Keep header (first part before any MOTIF)
    header = parts[0] if not parts[0].startswith('MOTIF') else ""
    
    # Find motifs matching the target IDs
    kept_motifs = []
    for part in parts:
        if part.startswith('MOTIF'):
            # Extract motif ID (first word after MOTIF)
            match = re.match(r'MOTIF\s+(\S+)', part)
            if match:
                motif_id = match.group(1)
                if motif_id in target_ids:
                    kept_motifs.append(part)
    
    # Write subset file
    with open(output_file, 'w') as f:
        f.write(header)
        for motif in kept_motifs:
            f.write(motif)
    
    print(f"\n Saved {len(kept_motifs)} motifs to {output_file}")
    return len(kept_motifs)

# Path to original database (same one used for TOMTOM)
databases = {
    "CISBP_RNA": "~/meme_db/motif_databases/CISBP-RNA/Mus_musculus.dna_encoded.meme",
    "RNA": "~/meme_db/motif_databases/RNA/Ray2013_rbp_Mus_musculus.dna_encoded.meme", 
    "miRBase": "~/meme_db/motif_databases/MIRBASE/22/Mus_musculus_mmu.dna_encoded.meme",
}

# Extract subset
os.makedirs("Data/FIMO", exist_ok=True)

for db_name, db_path in databases.items():
    full_path = os.path.expanduser(db_path)
    output_path = f"Data/FIMO/filtered_{db_name}.meme"
    extract_motifs_from_meme_db(full_path, all_targets, output_path)
# Out:
#  Saved 19 motifs to Data/FIMO/filtered_CISBP_RNA.meme
#
#  Saved 4 motifs to Data/FIMO/filtered_RNA.meme
#
#  Saved 165 motifs to Data/FIMO/filtered_miRBase.meme

# %% [markdown]
# ### Run FIMO (all transcripts against identified motifs)

# %%
fimo_path = "/home/jingqi/miniconda3/envs/rnalocate_old/bin/fimo"
motif_file = "Data/FIMO/all_filtered_motifs.meme"
fasta_file = "Data/Raw/FASTA.txt"
output_dir = "Data/FIMO/result_all_transcripts"

fimo_cmd = [
    fimo_path,
    "--oc", output_dir,
    "--thresh", "0.0001",
    motif_file, 
    fasta_file 
]

subprocess.run(fimo_cmd, check=True)
# Out:
# Using motif +M004_0.6 of width 7.
# Using motif -M004_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.991031
# Using motif +M033_0.6 of width 8.
# Using motif -M033_0.6 of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +M042_0.6 of width 7.
# Using motif -M042_0.6 of width 7.
# Computing q-values.
# Using motif +M043_0.6 of width 7.
# Using motif -M043_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.930196
# Using motif +M044_0.6 of width 7.
# Using motif -M044_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.775926
# Using motif +M049_0.6 of width 7.
# Using motif -M049_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965677
# Using motif +M054_0.6 of width 7.
# Using motif -M054_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.795962
# Using motif +M061_0.6 of width 7.
# Using motif -M061_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.930827
# Using motif +M065_0.6 of width 7.
# Using motif -M065_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.95375
# Using motif +M070_0.6 of width 8.
# Using motif -M070_0.6 of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.975978
# Using motif +M126_0.6 of width 7.
# Using motif -M126_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.933245
# Using motif +M145_0.6 of width 7.
# Using motif -M145_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.921417
# Using motif +M149_0.6 of width 7.
# Using motif -M149_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998492
# Using motif +M157_0.6 of width 7.
# Using motif -M157_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.985668
# Using motif +M175_0.6 of width 7.
# Using motif -M175_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.992205
# Using motif +M227_0.6 of width 7.
# Using motif -M227_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.989072
# Using motif +M228_0.6 of width 7.
# Using motif -M228_0.6 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999293
# Using motif +M307_0.6 of width 5.
# Using motif -M307_0.6 of width 5.
# Computing q-values.
# Using motif +M328_0.6 of width 14.
# Using motif -M328_0.6 of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998995
# Using motif +RNCMPT00062 of width 7.
# Using motif -RNCMPT00062 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +RNCMPT00239 of width 8.
# Using motif -RNCMPT00239 of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.987958
# Using motif +RNCMPT00215 of width 8.
# Using motif -RNCMPT00215 of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +RNCMPT00051 of width 7.
# Using motif -RNCMPT00051 of width 7.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.951407
# Using motif +mmu-miR-124-3p of width 20.
# Using motif -mmu-miR-124-3p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.983784
# Using motif +mmu-miR-140-3p of width 21.
# Using motif -mmu-miR-140-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.964255
# Using motif +mmu-miR-149-3p of width 22.
# Using motif -mmu-miR-149-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923846
# Using motif +mmu-miR-186-5p of width 22.
# Using motif -mmu-miR-186-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998191
# Using motif +mmu-miR-201-3p of width 23.
# Using motif -mmu-miR-201-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.983825
# Using motif +mmu-miR-204-5p of width 22.
# Using motif -mmu-miR-204-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.950336
# Using motif +mmu-miR-298-5p of width 23.
# Using motif -mmu-miR-298-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.946145
# Using motif +mmu-miR-106a-3p of width 23.
# Using motif -mmu-miR-106a-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952349
# Using motif +mmu-miR-30c-1-3p of width 22.
# Using motif -mmu-miR-30c-1-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.969825
# Using motif +mmu-miR-30c-2-3p of width 22.
# Using motif -mmu-miR-30c-2-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.96805
# Using motif +mmu-miR-22-5p of width 22.
# Using motif -mmu-miR-22-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.973373
# Using motif +mmu-miR-22-3p of width 22.
# Using motif -mmu-miR-22-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.980874
# Using motif +mmu-miR-322-5p of width 22.
# Using motif -mmu-miR-322-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.973516
# Using motif +mmu-miR-326-5p of width 24.
# Using motif -mmu-miR-326-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.909118
# Using motif +mmu-miR-328-5p of width 22.
# Using motif -mmu-miR-328-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.873557
# Using motif +mmu-miR-329-3p of width 22.
# Using motif -mmu-miR-329-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.986
# Using motif +mmu-miR-346-3p of width 22.
# Using motif -mmu-miR-346-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.899028
# Using motif +mmu-miR-17-3p of width 22.
# Using motif -mmu-miR-17-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.968966
# Using motif +mmu-miR-216a-3p of width 22.
# Using motif -mmu-miR-216a-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.98911
# Using motif +mmu-miR-211-5p of width 22.
# Using motif -mmu-miR-211-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.937267
# Using motif +mmu-miR-362-3p of width 22.
# Using motif -mmu-miR-362-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.995025
# Using motif +mmu-miR-20b-3p of width 22.
# Using motif -mmu-miR-20b-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.9616
# Using motif +mmu-miR-675-5p of width 22.
# Using motif -mmu-miR-675-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923636
# Using motif +mmu-miR-744-5p of width 22.
# Using motif -mmu-miR-744-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.914621
# Using motif +mmu-miR-1249-5p of width 25.
# Using motif -mmu-miR-1249-5p of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.934793
# Using motif +mmu-miR-762 of width 22.
# Using motif -mmu-miR-762 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.908794
# Using motif +mmu-miR-672-3p of width 21.
# Using motif -mmu-miR-672-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.969669
# Using motif +mmu-miR-673-3p of width 23.
# Using motif -mmu-miR-673-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.892214
# Using motif +mmu-miR-497a-5p of width 22.
# Using motif -mmu-miR-497a-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965509
# Using motif +mmu-miR-423-5p of width 23.
# Using motif -mmu-miR-423-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.937089
# Using motif +mmu-miR-669c-3p of width 22.
# Using motif -mmu-miR-669c-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998081
# Using motif +mmu-miR-698-5p of width 21.
# Using motif -mmu-miR-698-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.946195
# Using motif +mmu-miR-701-5p of width 21.
# Using motif -mmu-miR-701-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.975692
# Using motif +mmu-miR-702-5p of width 21.
# Using motif -mmu-miR-702-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.961197
# Using motif +mmu-miR-712-5p of width 21.
# Using motif -mmu-miR-712-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.913628
# Using motif +mmu-miR-343 of width 20.
# Using motif -mmu-miR-343 of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922484
# Using motif +mmu-miR-466f-3p of width 21.
# Using motif -mmu-miR-466f-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998894
# Using motif +mmu-miR-467c-5p of width 22.
# Using motif -mmu-miR-467c-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999293
# Using motif +mmu-miR-504-3p of width 22.
# Using motif -mmu-miR-504-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.939873
# Using motif +mmu-miR-466i-3p of width 22.
# Using motif -mmu-miR-466i-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.996869
# Using motif +mmu-miR-467f of width 21.
# Using motif -mmu-miR-467f of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mmu-miR-1903 of width 22.
# Using motif -mmu-miR-1903 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.9584
# Using motif +mmu-miR-1906 of width 22.
# Using motif -mmu-miR-1906 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.938974
# Using motif +mmu-miR-1907 of width 22.
# Using motif -mmu-miR-1907 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.954268
# Using motif +mmu-miR-1893 of width 22.
# Using motif -mmu-miR-1893 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.831262
# Using motif +mmu-miR-1930-3p of width 22.
# Using motif -mmu-miR-1930-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.955467
# Using motif +mmu-miR-1933-3p of width 22.
# Using motif -mmu-miR-1933-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.970143
# Using motif +mmu-miR-1941-5p of width 24.
# Using motif -mmu-miR-1941-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.96046
# Using motif +mmu-miR-1954 of width 21.
# Using motif -mmu-miR-1954 of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.959294
# Using motif +mmu-miR-1982-5p of width 20.
# Using motif -mmu-miR-1982-5p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.931469
# Using motif +mmu-miR-2136 of width 21.
# Using motif -mmu-miR-2136 of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965109
# Using motif +mmu-miR-3057-3p of width 22.
# Using motif -mmu-miR-3057-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.930897
# Using motif +mmu-miR-3064-3p of width 22.
# Using motif -mmu-miR-3064-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.966849
# Using motif +mmu-miR-3074-5p of width 22.
# Using motif -mmu-miR-3074-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.945325
# Using motif +mmu-miR-3076-5p of width 24.
# Using motif -mmu-miR-3076-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.937143
# Using motif +mmu-miR-466m-3p of width 22.
# Using motif -mmu-miR-466m-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999598
# Using motif +mmu-miR-466n-5p of width 22.
# Using motif -mmu-miR-466n-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.98
# Using motif +mmu-miR-3087-5p of width 21.
# Using motif -mmu-miR-3087-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952606
# Using motif +mmu-miR-3088-3p of width 23.
# Using motif -mmu-miR-3088-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.994898
# Using motif +mmu-miR-3090-5p of width 21.
# Using motif -mmu-miR-3090-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.932394
# Using motif +mmu-miR-3090-3p of width 22.
# Using motif -mmu-miR-3090-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935143
# Using motif +mmu-miR-3102-5p.2-5p of width 21.
# Using motif -mmu-miR-3102-5p.2-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923898
# Using motif +mmu-miR-3104-5p of width 25.
# Using motif -mmu-miR-3104-5p of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.893435
# Using motif +mmu-miR-3966 of width 21.
# Using motif -mmu-miR-3966 of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.913509
# Using motif +mmu-miR-3473b of width 20.
# Using motif -mmu-miR-3473b of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.941342
# Using motif +mmu-miR-5110 of width 25.
# Using motif -mmu-miR-5110 of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.943333
# Using motif +mmu-miR-5113 of width 23.
# Using motif -mmu-miR-5113 of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965341
# Using motif +mmu-miR-5120 of width 23.
# Using motif -mmu-miR-5120 of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.941295
# Using motif +mmu-miR-466q of width 20.
# Using motif -mmu-miR-466q of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.982976
# Using motif +mmu-miR-5126 of width 22.
# Using motif -mmu-miR-5126 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.828113
# Using motif +mmu-miR-5130 of width 24.
# Using motif -mmu-miR-5130 of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.880583
# Using motif +mmu-miR-5627-5p of width 22.
# Using motif -mmu-miR-5627-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.888952
# Using motif +mmu-miR-5627-3p of width 24.
# Using motif -mmu-miR-5627-3p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.891429
# Using motif +mmu-miR-6342 of width 22.
# Using motif -mmu-miR-6342 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.9535
# Using motif +mmu-miR-6379 of width 22.
# Using motif -mmu-miR-6379 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.949441
# Using motif +mmu-miR-6385 of width 21.
# Using motif -mmu-miR-6385 of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.972527
# Using motif +mmu-miR-6416-3p of width 21.
# Using motif -mmu-miR-6416-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.988254
# Using motif +mmu-miR-6418-5p of width 21.
# Using motif -mmu-miR-6418-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.939012
# Using motif +mmu-miR-6419 of width 22.
# Using motif -mmu-miR-6419 of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965647
# Using motif +mmu-miR-6539 of width 24.
# Using motif -mmu-miR-6539 of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.946087
# Using motif +mmu-miR-6900-5p of width 24.
# Using motif -mmu-miR-6900-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.911667
# Using motif +mmu-miR-6904-5p of width 22.
# Using motif -mmu-miR-6904-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.943913
# Using motif +mmu-miR-6911-5p of width 23.
# Using motif -mmu-miR-6911-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.920154
# Using motif +mmu-miR-6912-5p of width 22.
# Using motif -mmu-miR-6912-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.949655
# Using motif +mmu-miR-6913-5p of width 22.
# Using motif -mmu-miR-6913-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.940915
# Using motif +mmu-miR-6914-5p of width 24.
# Using motif -mmu-miR-6914-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.909552
# Using motif +mmu-miR-6916-5p of width 21.
# Using motif -mmu-miR-6916-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.959771
# Using motif +mmu-miR-6919-3p of width 21.
# Using motif -mmu-miR-6919-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.897313
# Using motif +mmu-miR-6921-5p of width 22.
# Using motif -mmu-miR-6921-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.941605
# Using motif +mmu-miR-6922-5p of width 23.
# Using motif -mmu-miR-6922-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.960506
# Using motif +mmu-miR-6928-3p of width 22.
# Using motif -mmu-miR-6928-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.980848
# Using motif +mmu-miR-6929-5p of width 21.
# Using motif -mmu-miR-6929-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.947765
# Using motif +mmu-miR-6931-5p of width 21.
# Using motif -mmu-miR-6931-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.927547
# Using motif +mmu-miR-6936-3p of width 21.
# Using motif -mmu-miR-6936-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.826729
# Using motif +mmu-miR-6937-5p of width 24.
# Using motif -mmu-miR-6937-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.984859
# Using motif +mmu-miR-6937-3p of width 23.
# Using motif -mmu-miR-6937-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.949444
# Using motif +mmu-miR-6940-5p of width 23.
# Using motif -mmu-miR-6940-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.918302
# Using motif +mmu-miR-6942-5p of width 21.
# Using motif -mmu-miR-6942-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.9584
# Using motif +mmu-miR-6945-5p of width 22.
# Using motif -mmu-miR-6945-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.899828
# Using motif +mmu-miR-6946-3p of width 20.
# Using motif -mmu-miR-6946-3p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.961573
# Using motif +mmu-miR-6947-3p of width 22.
# Using motif -mmu-miR-6947-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935745
# Using motif +mmu-miR-6953-5p of width 26.
# Using motif -mmu-miR-6953-5p of width 26.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.932453
# Using motif +mmu-miR-6954-3p of width 21.
# Using motif -mmu-miR-6954-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.920678
# Using motif +mmu-miR-6958-5p of width 22.
# Using motif -mmu-miR-6958-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.950683
# Using motif +mmu-miR-6964-3p of width 20.
# Using motif -mmu-miR-6964-3p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.969756
# Using motif +mmu-miR-6966-5p of width 21.
# Using motif -mmu-miR-6966-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922143
# Using motif +mmu-miR-6967-5p of width 21.
# Using motif -mmu-miR-6967-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952025
# Using motif +mmu-miR-6968-5p of width 22.
# Using motif -mmu-miR-6968-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.887862
# Using motif +mmu-miR-6979-5p of width 20.
# Using motif -mmu-miR-6979-5p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.93369
# Using motif +mmu-miR-6980-5p of width 22.
# Using motif -mmu-miR-6980-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.92557
# Using motif +mmu-miR-6981-5p of width 26.
# Using motif -mmu-miR-6981-5p of width 26.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.968721
# Using motif +mmu-miR-6988-5p of width 21.
# Using motif -mmu-miR-6988-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923134
# Using motif +mmu-miR-6990-5p of width 21.
# Using motif -mmu-miR-6990-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.924416
# Using motif +mmu-miR-6991-3p of width 22.
# Using motif -mmu-miR-6991-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.926992
# Using motif +mmu-miR-6998-3p of width 22.
# Using motif -mmu-miR-6998-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.968757
# Using motif +mmu-miR-7001-5p of width 23.
# Using motif -mmu-miR-7001-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.909353
# Using motif +mmu-miR-7005-5p of width 22.
# Using motif -mmu-miR-7005-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.907805
# Using motif +mmu-miR-7011-5p of width 23.
# Using motif -mmu-miR-7011-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.960782
# Using motif +mmu-miR-7013-3p of width 24.
# Using motif -mmu-miR-7013-3p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.960876
# Using motif +mmu-miR-7016-5p of width 21.
# Using motif -mmu-miR-7016-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952235
# Using motif +mmu-miR-7024-5p of width 21.
# Using motif -mmu-miR-7024-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935
# Using motif +mmu-miR-7028-5p of width 23.
# Using motif -mmu-miR-7028-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.914627
# Using motif +mmu-miR-7030-5p of width 22.
# Using motif -mmu-miR-7030-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.93103
# Using motif +mmu-miR-7031-5p of width 23.
# Using motif -mmu-miR-7031-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.960426
# Using motif +mmu-miR-7032-5p of width 26.
# Using motif -mmu-miR-7032-5p of width 26.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.915817
# Using motif +mmu-miR-7033-5p of width 23.
# Using motif -mmu-miR-7033-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.945697
# Using motif +mmu-miR-7034-5p of width 21.
# Using motif -mmu-miR-7034-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.902778
# Using motif +mmu-miR-7049-3p of width 21.
# Using motif -mmu-miR-7049-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.917444
# Using motif +mmu-miR-7050-5p of width 21.
# Using motif -mmu-miR-7050-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952515
# Using motif +mmu-miR-7060-5p of width 22.
# Using motif -mmu-miR-7060-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.997732
# Using motif +mmu-miR-7069-5p of width 23.
# Using motif -mmu-miR-7069-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.927143
# Using motif +mmu-miR-7075-5p of width 21.
# Using motif -mmu-miR-7075-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.94
# Using motif +mmu-miR-7076-5p of width 21.
# Using motif -mmu-miR-7076-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.953146
# Using motif +mmu-miR-7078-5p of width 20.
# Using motif -mmu-miR-7078-5p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.959865
# Using motif +mmu-miR-7079-5p of width 22.
# Using motif -mmu-miR-7079-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.906167
# Using motif +mmu-miR-7080-5p of width 23.
# Using motif -mmu-miR-7080-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.977253
# Using motif +mmu-miR-7083-5p of width 21.
# Using motif -mmu-miR-7083-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.881905
# Using motif +mmu-miR-7085-3p of width 22.
# Using motif -mmu-miR-7085-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.93888
# Using motif +mmu-miR-7086-5p of width 21.
# Using motif -mmu-miR-7086-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.983102
# Using motif +mmu-miR-7087-5p of width 21.
# Using motif -mmu-miR-7087-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.947093
# Using motif +mmu-miR-7088-5p of width 25.
# Using motif -mmu-miR-7088-5p of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.930097
# Using motif +mmu-miR-7093-5p of width 22.
# Using motif -mmu-miR-7093-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.994388
# Using motif +mmu-miR-7115-5p of width 24.
# Using motif -mmu-miR-7115-5p of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.905532
# Using motif +mmu-miR-7119-5p of width 21.
# Using motif -mmu-miR-7119-5p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.930186
# Using motif +mmu-miR-7222-3p of width 23.
# Using motif -mmu-miR-7222-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.946258
# Using motif +mmu-miR-7226-5p of width 26.
# Using motif -mmu-miR-7226-5p of width 26.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.921818
# Using motif +mmu-miR-7235-5p of width 18.
# Using motif -mmu-miR-7235-5p of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.954205
# Using motif +mmu-miR-7648-3p of width 21.
# Using motif -mmu-miR-7648-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.89625
# Using motif +mmu-miR-7662-5p of width 22.
# Using motif -mmu-miR-7662-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.91776
# Using motif +mmu-miR-7669-3p of width 23.
# Using motif -mmu-miR-7669-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.941161
# Using motif +mmu-miR-7670-3p of width 23.
# Using motif -mmu-miR-7670-3p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.961783
# Using motif +mmu-miR-7672-3p of width 21.
# Using motif -mmu-miR-7672-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935588
# Using motif +mmu-miR-7676-5p of width 23.
# Using motif -mmu-miR-7676-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.933974
# Using motif +mmu-miR-1258-5p of width 22.
# Using motif -mmu-miR-1258-5p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.982659
# Using motif +mmu-miR-7688-5p of width 23.
# Using motif -mmu-miR-7688-5p of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.963401
# Using motif +mmu-miR-8100 of width 23.
# Using motif -mmu-miR-8100 of width 23.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.953488
# Using motif +mmu-miR-497b of width 24.
# Using motif -mmu-miR-497b of width 24.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.96443
# Using motif +mmu-miR-8103 of width 21.
# Using motif -mmu-miR-8103 of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.929474
# Using motif +mmu-miR-12180-3p of width 18.
# Using motif -mmu-miR-12180-3p of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.967356
# Using motif +mmu-miR-12183-5p of width 18.
# Using motif -mmu-miR-12183-5p of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.957647
# Using motif +mmu-miR-12185-5p of width 25.
# Using motif -mmu-miR-12185-5p of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922937
# Using motif +mmu-miR-3473h-5p of width 20.
# Using motif -mmu-miR-3473h-5p of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.94759
# Using motif +mmu-miR-12196-3p of width 22.
# Using motif -mmu-miR-12196-3p of width 22.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.977528
# Using motif +mmu-miR-12197-3p of width 18.
# Using motif -mmu-miR-12197-3p of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.885113
# Using motif +mmu-miR-12201-3p of width 21.
# Using motif -mmu-miR-12201-3p of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.955879
# CompletedProcess(args=['/home/jingqi/miniconda3/envs/rnalocate_old/bin/fimo', '--oc', 'Data/FIMO/result_all_transcripts', '--thresh', '0.0001', 'Data/FIMO/all_filtered_motifs.meme', 'Data/Raw/FASTA.txt'], returncode=0)

# %% [markdown]
# ### Blend in SCL

# %%
# CORRECT HEADER
fimo_cols = [
    "motif_id", "sequence_name", "start", "stop", "strand", 
    "score", "p-value", "q-value", "matched_sequence"
]

fimo_df = pd.read_csv(
    "Data/FIMO/result_all_transcripts/fimo.txt", 
    sep='\t', 
    comment='#', 
    header=None, 
    names=fimo_cols
)

filtered_df = fimo_df[fimo_df['q-value'] < 0.05]

print(f"n\ Hits with q-value < 0.05: {len(filtered_df)}")

gene_lookup = {}

df = pd.read_csv("Data/Raw/gene_transcript_matrix.csv")

# Iterate row by row to build the dictionary
for index, row in df.iterrows():
    gene_symbol = row['Gene_Symbol']
    transcripts = row.drop('Gene_Symbol').dropna()
    
    for transcript in transcripts:
        if isinstance(transcript, str):
            ids = transcript.strip()
            gene_lookup[ids] = gene_symbol

print(f"Loaded {len(gene_lookup)} gene-transcript mappings")
print(f"Unique Genes found: {df['Gene_Symbol'].nunique()}")

df_longer = pd.read_csv("Data/TOMTOM/tomtom_longer_filtered.csv")
df_shorter = pd.read_csv("Data/TOMTOM/tomtom_shorter_filtered.csv")

# Combine and create mapping class, bucket
motif_to_cluster = {}

for _, row in df_longer.iterrows():
    target = row['Target']
    cluster = f"{row['Class']}_{row['Bucket']}"
    if target not in motif_to_cluster:
        motif_to_cluster[target] = cluster

for _, row in df_shorter.iterrows():
    target = row['Target']
    cluster = f"{row['Class']}_{row['Bucket']}"
    if target not in motif_to_cluster:
        motif_to_cluster[target] = cluster

print(f"Mapped {len(motif_to_cluster)} motifs to clusters")


prob_df = pd.read_csv("Data/Main/Probabilities.csv")
prob_df = prob_df.set_index('sequence_id')

prob_cols = {
    'chromatin': 'chromatin_prob',
    'cytoplasm': 'cytoplasm_prob',
    'cytosol': 'cytosol_prob',
    'ER': 'endoplasmic reticulum_prob',
    'extracellular': 'extracellular region_prob',
    'membrane': 'membrane_prob',
    'mitochondrion': 'mitochondrion_prob',
    'nucleolus': 'nucleolus_prob',
    'nucleoplasm': 'nucleoplasm_prob',
    'nucleus': 'nucleus_prob',
    'ribosome': 'ribosome_prob'
}

results = []

for _, row in filtered_df.iterrows():
    motif_id = row['motif_id']
    transcript = row['sequence_name']
    p_value = row['p-value']
    q_value = row['q-value']
    
    # Get gene for this transcript
    gene = gene_lookup.get(transcript, 'Unknown')
    
    # Get cluster for this motif
    cluster = motif_to_cluster.get(motif_id, None)
    if not cluster:
        continue
    
    # Parse class and bucket
    parts = cluster.rsplit('_', 1)
    if len(parts) != 2:
        continue
    class_name, bucket = parts
    
    # Get transcript probability
    if transcript not in prob_df.index:
        continue
    
    # Find the probability column
    prob_col = prob_cols.get(class_name, None)
    if not prob_col:
        for col in prob_df.columns:
            if class_name.lower() in col.lower():
                prob_col = col
                break
    
    if not prob_col:
        continue
    
    prob_value = prob_df.loc[transcript, prob_col]
    
    # Validate based on bucket
    if bucket == 'positive':
        expected = "High"
        match = prob_value > 0.5
    else:
        expected = "Low"
        match = prob_value < 0.5
    
    results.append({
        'Gene': gene,
        'Transcript': transcript,
        'Motif': motif_id,
        'Cluster': cluster,
        'Probability': prob_value,
        'Expected': expected,
        'Match': '✓' if match else '✗',
        'q_value': q_value
    })

result_df = pd.DataFrame(results)

# Sort: genes alphabetically, Unknown at the end
result_df['_sort_key'] = result_df['Gene'].apply(lambda x: (1, '') if x == 'Unknown' else (0, x.lower()))
result_df = result_df.sort_values(by=['_sort_key', 'Gene', 'Transcript'])
result_df = result_df.drop(columns=['_sort_key'])

# Reset index
result_df = result_df.reset_index(drop=True)

# Save
result_df.to_csv("Data/FIMO/motifs_validated.csv", index=False)
print(f"\n Total validated hits: {len(result_df)}")

# Keep only the validated matches (✓)
clean_df = result_df[result_df['Match'] == '✓'].copy()
clean_df = clean_df[result_df['Gene'] != 'Unknown']

# Drop the validation columns 
cols_to_drop = ['Probability', 'Expected', 'Match']
clean_df = clean_df.drop(columns=cols_to_drop, errors='ignore')

output_file = "Data/FIMO/motifs_validated_filtered.csv"
clean_df.to_csv(output_file, index=False)

if not result_df.empty:
    matches = (result_df['Match'] == '✓').sum()
    total = len(result_df)
    print(f"Matching predictions: {matches}/{total} ({100*matches/total:.1f}%)")
    
    # Gene stats
    print(f"Unique genes: {result_df[result_df['Gene'] != 'Unknown']['Gene'].nunique()}")
    
    print(f"\nBy cluster:")
    for cluster in sorted(result_df['Cluster'].unique()):
        subset = result_df[result_df['Cluster'] == cluster]
        m = (subset['Match'] == '✓').sum()
        t = len(subset)
        print(f"  {cluster}: {m}/{t} ({100*m/t:.1f}%)")
# Out:
# Loaded 5788 gene-transcript mappings
# Unique Genes found: 728
# Mapped 188 motifs to clusters
#
#  Total validated hits: 50432
# Matching predictions: 29750/50432 (59.0%)
# Unique genes: 709
#
# By cluster:
# /tmp/ipykernel_3124637/2164612541.py:130: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[result_df['Gene'] != 'Unknown']
#   ER_negative: 1025/1049 (97.7%)
#   ER_positive: 6/200 (3.0%)
#   chromatin_negative: 62/122 (50.8%)
#   chromatin_positive: 14230/29490 (48.3%)
#   cytoplasm_negative: 142/322 (44.1%)
#   cytoplasm_positive: 86/138 (62.3%)
#   extracellular_negative: 0/18 (0.0%)
#   extracellular_positive: 267/271 (98.5%)
#   membrane_negative: 40/71 (56.3%)
#   mitochondrion_negative: 412/1402 (29.4%)
#   mitochondrion_positive: 14/19 (73.7%)
#   nucleolus_negative: 14/24 (58.3%)
#   nucleoplasm_negative: 1133/2522 (44.9%)
#   nucleoplasm_positive: 979/1759 (55.7%)
#   nucleus_positive: 11144/12271 (90.8%)
#   ribosome_negative: 196/754 (26.0%)

# %% [markdown]
# ### Compress by Motifs

# %%
# compress all the same motifs, check if one motif hits two or more localization

input_file = "Data/FIMO/motifs_validated_filtered.csv"
df = pd.read_csv(input_file)
# This converts "1.2e-5" strings to numbers
df['q_value'] = pd.to_numeric(df['q_value'])

#  Define Fisher's Method Function
def fisher_score(group):
    q_values = group['q_value'].values
    # Calculate Chi-Squared Statistic: -2 * sum(ln(q))
    chi2_stat = -2 * np.sum(np.log(q_values))
    # Degrees of freedom = 2 * number of tests
    df_chi2 = 2 * len(q_values)
    # Calculate combined p-value (Upper tail of Chi2 distribution)
    p_val = stats.chi2.sf(chi2_stat, df_chi2)
    return pd.Series({'Hits': len(q_values), 'Fisher_score': chi2_stat, 'p_adjusted': p_val})

# Filter out motifs that appear in more than one cluster
cluster_counts = df.groupby('Motif')['Cluster'].nunique()
valid_motifs = cluster_counts[cluster_counts == 1].index

# Filter the main dataframe to keep only these valid motifs
df_valid = df[df['Motif'].isin(valid_motifs)].copy()

print(f"  - Original unique motifs: {df['Motif'].nunique()}")
print(f"  - Motifs with conflicting clusters (discarded): {df['Motif'].nunique() - len(valid_motifs)}")
print(f"  - Motifs kept: {len(valid_motifs)}")

# Group by motif and cluster 
agg_df = df_valid.groupby(['Motif', 'Cluster']).apply(fisher_score).reset_index()

# Sort
agg_df = agg_df.sort_values('Fisher_score', ascending = False)

# Format the Output
agg_df = agg_df[['Motif', 'Cluster', 'Hits', 'Fisher_score', 'p_adjusted']]

output_file = "Data/FIMO/a_aggregated.csv"
agg_df.to_csv(output_file, index=False)

print(f"\n Aggregated file saved to: {output_file}")
# Out:
#   - Original unique motifs: 89
#   - Motifs with conflicting clusters (discarded): 0
#   - Motifs kept: 89
#
# Success! Aggregated file saved to: Data/FIMO/motifs_aggregated.csv

# %% [markdown]
# ### Compress by transcript (then motif)

# %%
# compress all the transcripts with the same motif, at least one hit being true is enough

df = pd.read_csv("Data/FIMO/motifs_validated_filtered.csv")

# Ensure numeric types and clean data
df['q_value'] = pd.to_numeric(df['q_value'])
df = df.dropna(subset=['q_value'])

def combined_pval(group):
    q_values = group['q_value'].values
    log_qs = np.log(q_values) 
    prob_all_false = np.exp(np.sum(log_qs))
    # Phred Score -logP
    phred_score = -(np.sum(log_qs) / np.log(10))
    return  pd.Series({
        'Counts': len(q_values),
        'p_adjusted': prob_all_false,
        'Phred_score': phred_score
    })

# We keep Site_Count and Best_Site_Q as useful secondary metrics
compressed_df = df.groupby(['Gene', 'Transcript', 'Motif', 'Cluster']).apply(combined_pval).reset_index()

# sorting, plus cluter the rows with the same gene together
compressed_df = compressed_df.sort_values(by=['Gene', 'Phred_score'], ascending=[True, False])
# compressed_df = compressed_df.sort_values('Phred_score', ascending = False)

output_file = "Data/FIMO/a_compressed_in_transcripts.csv"
compressed_df.to_csv(output_file, index=False)

print(f"Compressed {len(df)} hits into {len(compressed_df)} unique transcript-motif pairs.")
print(f"Results saved to: {output_file}")
# Out:
# Compressed 29720 hits into 10450 unique transcript-motif pairs.
# Results saved to: Data/FIMO/a_compressed_in_transcripts.csv

# %% [markdown]
# ### Compress by motif on transcript-compressed data (can skip)

# %%
# mostly like the cell above above

input_file = "Data/FIMO/a_compressed_in_transcripts.csv"
df = pd.read_csv(input_file)
# This converts "1.2e-5" strings to numbers
df['q_value'] = pd.to_numeric(df['p_adjusted'])

#  Define Fisher's Method Function
def fisher_score(group):
    q_values = group['q_value'].values
    # Calculate Chi-Squared Statistic: -2 * sum(ln(q))
    chi2_stat = -2 * np.sum(np.log(q_values + 10e-100))
    # Degrees of freedom = 2 * number of tests
    df_chi2 = 2 * len(q_values)
    # Calculate combined p-value (Upper tail of Chi2 distribution)
    p_val = stats.chi2.sf(chi2_stat, df_chi2)
    return pd.Series({'Hits': len(q_values), 'Fisher_score': chi2_stat, 'p_adjusted': p_val})

# Group by motif and cluster 
agg_df = df.groupby(['Motif', 'Cluster']).apply(fisher_score).reset_index()

# Sort
agg_df = agg_df.sort_values('Fisher_score', ascending = False)

# Format the Output
agg_df = agg_df[['Motif', 'Cluster', 'Hits', 'Fisher_score', 'p_adjusted']]

output_file = "Data/FIMO/a_aggregated_delicate.csv"
agg_df.to_csv(output_file, index=False)

print(f"\n Aggregated file saved to: {output_file}")
# Out:
#   - Original unique motifs: 89
#   - Motifs with conflicting clusters (discarded): 0
#   - Motifs kept: 89
#
# Success! Aggregated file saved to: Data/FIMO/a_aggregated_delicate.csv

# %% [markdown]
# ### Compress by cluster

# %%
df = pd.read_csv("Data/FIMO/motifs_validated_filtered.csv")
df_selected = df[['Gene', 'Transcript', 'Cluster']].drop_duplicates().copy()

# rule 1: Merge same transcript with same cluster
# Record the "Cluster Distribution" for each Transcript
tx_clusters = df_selected.groupby(['Gene', 'Transcript'])['Cluster'].apply(lambda x: tuple(sorted(x))).reset_index(name='Subcellular_Distribution')

# rule 2: Discard uniform genes
# Count the distribution sets for each gene
gene_dist_counts = tx_clusters.groupby('Gene')['Subcellular_Distribution'].nunique()

# Only keep genes with differential cluster distributions
valid_genes = gene_dist_counts[gene_dist_counts > 1].index
# Filter the dataframe
final_df = df_selected[df_selected['Gene'].isin(valid_genes)].copy()

# Sort for readability
final_df = final_df.sort_values(by=['Gene', 'Transcript', 'Cluster'])

output_file = "Data/FIMO/a_differential_isoforms.csv"
final_df.to_csv(output_file, index=False)

print(f"Saved to: {output_file}")
print(f"Genes kept: {len(valid_genes)}")
print(f"Final rows: {len(final_df)}")
# Out:
# Saved to: Data/FIMO/a_differential_isoforms.csv
# Genes kept: 584
# Final rows: 5953

# %% [markdown]
# ### Comress by cluster (only keep positive distribution)

# %%
df = pd.read_csv("Data/FIMO/motifs_validated_filtered.csv")

# Before everything, filter for positive
df_positive = df[df['Cluster'].str.endswith('_positive')].copy()
# Remove the '_positive' suffix from the names
df_positive['Localization'] = df_positive['Cluster'].str.replace('_positive', '')

df_selected = df_positive[['Gene', 'Transcript', 'Localization']].drop_duplicates().copy()

# rule 1: Merge same transcript with same cluster
# Record the "Cluster Distribution" for each Transcript
tx_clusters = df_selected.groupby(['Gene', 'Transcript'])['Localization'].apply(lambda x: tuple(sorted(x))).reset_index(name='Subcellular_Distribution')

# rule 2: Discard uniform genes
# Count the distribution sets for each gene
gene_dist_counts = tx_clusters.groupby('Gene')['Subcellular_Distribution'].nunique()

# Only keep genes with differential cluster distributions
valid_genes = gene_dist_counts[gene_dist_counts > 1].index
# Filter the dataframe
final_df = df_selected[df_selected['Gene'].isin(valid_genes)].copy()

# Sort for readability
final_df = final_df.sort_values(by=['Gene', 'Transcript', 'Localization'])

output_file = "Data/FIMO/a_positive_differential_isoforms.csv"
final_df.to_csv(output_file, index=False)

print(f"Saved to: {output_file}")
print(f"Genes kept: {len(valid_genes)}")
print(f"Final rows: {len(final_df)}")
# Out:
# Saved to: Data/FIMO/a_positive_differential_isoforms.csv
# Genes kept: 433
# Final rows: 3208

# %%
df = pd.read_csv("Data/FIMO/a_positive_differential_isoforms.csv")

# 3. Create a sequence number for each localization on a transcript
df['Loc_Num'] = df.groupby(['Gene', 'Transcript']).cumcount() + 1
df['Loc_Num'] = 'Localization_' + df['Loc_Num'].astype(str)

# 4. Pivot the table. This takes the 'Loc_Num' column and turns its values into brand new column headers
df_wide = df.pivot(
    index=['Gene', 'Transcript'], 
    columns='Loc_Num', 
    values='Localization'
).reset_index()

# Clean up the internal column names to make it look nice
df_wide.columns.name = None

# Sort the dataframe for easy reading
df_wide = df_wide.sort_values(by=['Gene', 'Transcript'])

output_file = "Data/FIMO/a_genewise.csv"
df_wide.to_csv(output_file, index=False)

print(f"Success! Compressed down to {len(df_wide)} unique transcripts.")
print(f"Saved to: {output_file}")
# Out:
# Success! Compressed down to 1961 unique transcripts.
# Saved to: Data/FIMO/a_genewise.csv
